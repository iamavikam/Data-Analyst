# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb

# %%
a=pd.read_csv("D:/download/Excle practice data/Untitled spreadsheet - iriss.csv.csv")
a.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sb.scatterplot(y="sepal_length",x="sepal_width",data=a,hue="sepal_width")
plt.show()

# %%
y=a[["sepal_length"]]
x=a[["sepal_width"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      sepal_width
# 46           3.8
# 67           2.7
# 56           3.3
# 113          2.5
# 55           2.8

# %%
x_test.head()
# Out:
#      sepal_width
# 83           2.7
# 102          3.0
# 73           2.8
# 136          3.4
# 90           2.6

# %%
y_test.head()
# Out:
#      sepal_length
# 83            6.0
# 102           7.1
# 73            6.1
# 136           6.3
# 90            5.5

# %%
y_train.head()
# Out:
#      sepal_length
# 46            5.1
# 67            5.8
# 56            6.3
# 113           5.7
# 55            5.7

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)
y_test.head()
# Out:
#      sepal_length
# 83            6.0
# 102           7.1
# 73            6.1
# 136           6.3
# 90            5.5

# %%
y_predict[0:7]
# Out:
# array([[5.96718596],
#        [5.88883901],
#        [5.94107031],
#        [5.7843764 ],
#        [5.99330161],
#        [5.88883901],
#        [5.99330161]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.732516913198873
